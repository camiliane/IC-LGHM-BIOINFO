# %%
# !pip install bravado
# Out:
# Requirement already satisfied: bravado in c:\users\camila - bioinfo\anaconda3\lib\site-packages (11.0.3)
# Requirement already satisfied: bravado-core>=5.16.1 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (6.1.1)
# Requirement already satisfied: msgpack in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (1.0.3)
# Requirement already satisfied: python-dateutil in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (2.8.2)
# Requirement already satisfied: pyyaml in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (6.0)
# Requirement already satisfied: requests>=2.17 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (2.31.0)
# Requirement already satisfied: six in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (1.16.0)
# Requirement already satisfied: simplejson in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (3.19.2)
# Requirement already satisfied: monotonic in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (1.6)
# Requirement already satisfied: typing-extensions in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado) (4.7.1)
# Requirement already satisfied: jsonref in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado-core>=5.16.1->bravado) (1.1.0)
# Requirement already satisfied: jsonschema[format-nongpl]>=2.5.1 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado-core>=5.16.1->bravado) (4.17.3)
# Requirement already satisfied: swagger-spec-validator>=2.0.1 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado-core>=5.16.1->bravado) (3.0.3)
# Requirement already satisfied: pytz in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from bravado-core>=5.16.1->bravado) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from requests>=2.17->bravado) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from requests>=2.17->bravado) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from requests>=2.17->bravado) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from requests>=2.17->bravado) (2024.2.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (0.18.0)
# Requirement already satisfied: fqdn in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (2.1)
# Requirement already satisfied: rfc3339-validator in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (0.1.1)
# Requirement already satisfied: uri-template in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\camila - bioinfo\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado) (1.2.3)

# %%
import pandas as pd
import numpy as np
from bravado.client import SwaggerClient

# %%
cbioportal = SwaggerClient.from_url('https://www.cbioportal.org/api/v2/api-docs',
                                    config={"validate_requests":False,"validate_responses":False,"validate_swagger_spec": False})

# %%
def mutation_to_maf(path):

    combined = pd.read_csv(path, sep="\t", dtype='object')
    studies = list(combined['Study ID'].unique())
    
    mutations_list = []
    df_list = []
    
    #carregando as mutações e os sample ID a partir de uma lista de estudos
    for studie in studies:
        mutations = cbioportal.Mutations.getMutationsInMolecularProfileBySampleListIdUsingGET(
            molecularProfileId='{}_mutations'.format(studie),
            sampleListId='{}_all'.format(studie),
            projection='DETAILED').result()
        
        mutations_list.append(mutations) 

    #transformando as mutações em dataframes
    for mutations in mutations_list:
        df = pd.DataFrame.from_dict([dict(
            {k:getattr(m,k) for k in dir(m)},
            **{k:getattr(m.gene,k) for k in dir(m.gene)}) for m in mutations])
        df.dropna()
        df_list.append(df)
    
    studie_mutations = pd.concat(df_list, axis=0) #concatenando os dataframes
    
    #escolhendo somente as colunas exigidas pelo maftools
    maf_ = studie_mutations[[#'alleleSpecificCopyNumber', 'aminoAcidChange', 'center', 
    'chr',
       #'driverFilter', 'driverFilterAnnotation', 'driverTiersFilter',
       #'driverTiersFilterAnnotation', 
    'endPosition', #'entrezGeneId', 'gene',
       #'keyword', 'molecularProfileId', 'mutationStatus', 
    'mutationType',
       #'namespaceColumns', 'ncbiBuild', 'normalAltCount', 'normalRefCount',
       #'patientId', 
    'proteinChange', #'proteinPosEnd', 'proteinPosStart',
       'referenceAllele',# 'refseqMrnaId', 
    'sampleId', 'startPosition',
       'studyId', 'tumorAltCount', 'tumorRefCount', 
    #'uniquePatientKey',
       #'uniqueSampleKey', 'validationStatus', 
    'variantAllele', 
    'variantType',
       #'geneticEntityId', 'type'
    'hugoGeneSymbol']]
    
    maf = maf_.drop_duplicates() 
    

    #renomeando para o maftools
    maf = maf.rename(columns={'hugoGeneSymbol':'Hugo_Symbol',
                    'sampleId':'Tumor_Sample_Barcode',
                    'proteinChange': 'Protein_Change',
                    'mutationType': 'Variant_Classification',
                    'variantType': 'Variant_Type',
                    'startPosition': 'Start_Position',
                    'endPosition': 'End_Position',
                    'referenceAllele':'Reference_Allele',
                    'variantAllele': 'Tumor_Seq_Allele2',
                          'studyId':'Study_ID'})
    
    return maf

# %%
list_genes = pd.read_csv("genes_leukemia/BALL.csv")
list_genes
# Out:
#          GENE  CNV  DEL  DUP
# 0       ASXL1    0    5    3
# 1        BRAF    1    6    5
# 2        CALR    0    3    1
# 3         CBL    0    6    5
# 4      CDKN2A    1   66   13
# 5      CDKN2B    1   57   10
# 6        ETV6    0   29    3
# 7        EZH2    0    7    5
# 8       FBXW7    0    4   23
# 9       GATA1    0    5   34
# 10      IKZF1    0   38    1
# 11       IL7R    1    1    7
# 12       JAK2    1   19   13
# 13        KIT    0    1   22
# 14       KRAS    0   10    1
# 15        NF1    0    6   22
# 16       NPM1    1    0    9
# 17       PHF6    0    7   31
# 18       PTEN    0    2   29
# 19      RUNX1    0    1   52
# 20     SETBP1    0    0   18
# 21      SH2B3    1    4    3
# 22      SRSF2    0    1   22
# 23       TET2    0    3   22
# 24       TP53    0    1   20
# 25      U2AF1    0    1   47
# 26      ZRSR2    0    6   36
# 27       ABL1    1    4    8
# 28     NOTCH1    0    4    9
# 29     CREBBP    0    1    2
# 30       IDH2    0    3    0
# 31        WT1    0    0    5
# 32      CEBPA    0    3    0
# 33  CHR_EVENT    0    1    0
# 34      CSF3R    1    3    1
# 35       FLT3    0    3    1
# 36       IDH1    0    3    1
# 37       JAK1    1    3    1
# 38        MPL    1    3    1
# 39       NRAS    0    3    1
# 40      SF3B1    0    3    1
# 41     DNMT3A    1    0    2
# 42       HRAS    0    0    3
# 43     PTPN11    0    0    2

# %%
leukemia = mutation_to_maf("combined_leukemia_studies.tsv")
# Out:
# C:\Users\Camila - bioinfo\AppData\Local\Temp\ipykernel_3156\1916385685.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   studie_mutations = pd.concat(df_list, axis=0) #concatenando os dataframes
#      chr  End_Position Variant_Classification Protein_Change Reference_Allele  \
# 0      4     106156043        Frame_Shift_Del     Q317Rfs*30                C
# 1      4     106190830        Frame_Shift_Del    V1371Sfs*77                G
# 2      5     170837544        Frame_Shift_Ins     W288Cfs*12                -
# 3      2      25457242      Missense_Mutation          R882H                C
# 4     11      32456652        Frame_Shift_Del      A82Pfs*15                C
# ...   ..           ...                    ...            ...              ...
# 1835  11       1272152      Missense_Mutation         T4681I                C
# 1836   7      75051473      Missense_Mutation          G688R                C
# 1837  16      33629937      Missense_Mutation           H54Q                C
# 1838   7     148964299      Missense_Mutation          R220K                G
# 1839   9     100085148      Missense_Mutation          R442H                G
#
#         Tumor_Sample_Barcode  Start_Position       Study_ID  tumorAltCount  \
# 0     aml_ohsu_2018_09-00705       106156043  aml_ohsu_2018           68.0
# 1     aml_ohsu_2018_09-00705       106190830  aml_ohsu_2018           28.0
# 2     aml_ohsu_2018_09-00705       170837543  aml_ohsu_2018           17.0
# 3     aml_ohsu_2018_10-00136        25457242  aml_ohsu_2018           11.0
# 4     aml_ohsu_2018_10-00136        32456652  aml_ohsu_2018           18.0
# ...                      ...             ...            ...            ...
# 1835         TCGA-AB-2988-03         1272152  laml_tcga_pub            1.0
# 1836         TCGA-AB-2803-03        75051473  laml_tcga_pub            1.0
# 1837         TCGA-AB-2980-03        33629937  laml_tcga_pub          110.0
# 1838         TCGA-AB-2868-03       148964299  laml_tcga_pub          103.0
# 1839         TCGA-AB-2917-03       100085148  laml_tcga_pub           30.0
#
#       tumorRefCount Tumor_Seq_Allele2 Variant_Type   Hugo_Symbol
# 0             151.0                 -          DEL          TET2
# 1              74.0                 -          DEL          TET2
# 2              59.0              TCTG          INS          NPM1
# 3              28.0                 T          SNP        DNMT3A
# 4              51.0                 -          DEL           WT1
# ...             ...               ...          ...           ...
# 1835            0.0                 T          SNP         MUC5B
# 1836            9.0                 G          SNP       POM121C
# 1837          557.0                 G          SNP  IGHV3OR16-13
# 1838          248.0                 A          SNP        ZNF783
# 1839          128.0                 A          SNP       CCDC180
#
# [47868 rows x 13 columns]

# %%
subset_leuk = leukemia[leukemia['Hugo_Symbol'].isin(list(list_genes['GENE']))]
subset_leuk['Hugo_Symbol'].unique()
# Out:
# array(['NPM1', 'WT1', 'SRSF2', 'IDH1', 'PHF6', 'JAK2', 'ZRSR2', 'CDKN2A',
#        'PTEN', 'GATA1'], dtype=object)

# %%
subset_leuk.to_csv("TALL_maf.txt", sep='\t')
